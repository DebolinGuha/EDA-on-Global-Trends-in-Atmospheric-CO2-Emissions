# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-mm-mlo.csv
# /kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-annmean-gl.csv
# /kaggle/input/global-trends-in-atmospheric-carbon-dioxide/combined_annual_co2_data.csv
# /kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-gr-mlo.csv
# /kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-mm-gl.csv
# /kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-annmean-mlo.csv
# /kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-gr-gl.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div style= "background-color:#F36262; padding: 10px;text-align:center;border-radius : 30px">
#     <h1>Global Trends in Atmospheric CO2 Emission</h1>
# </div>

# %% [markdown]
# <div style= "background-color:gray; padding: 10px;border-radius : 30px">
#     <h3>About dataset</h3>
# </div>
# <br>
# <div style= "background-color:#E1E1E1; padding: 10px;border-radius : 30px">
#     <p>Data are sourced from the US Government's Earth System Research Laboratory, Global Monitoring Division. Two main series are provided: the Mauna Loa series (which has the longest continuous series since 1958) and a Global Average series (a global average over marine surface sites).
#
# Data are reported as a dry air mole fraction defined as the number of molecules of carbon dioxide divided by the number of all molecules in air, including CO2 itself, after water vapor has been removed. The mole fraction is expressed as parts per million (ppm). Example: 0.000400 is expressed as 400 ppm
#
# Date: Represents the year and month when the CO2 measurements were taken, formatted as 'YYYY-MM'.
#
# Decimal Date: Indicates the date in a decimal year format, calculated as the year plus the fraction of the year that has passed by the date of the measurement
#
# Average: The average monthly concentration of atmospheric CO2 measured in parts per million (ppm).
#
# Interpolated: The interpolated value of CO2 concentration for months with missing data, ensuring a continuous time series
#
# Trend: This column shows the value of CO2 concentration adjusted to remove the seasonal cycle, providing a clearer view of the long-term trend.
#
# Number of Days: Indicates the number of days in the month that valid measurements were available.
#
# Year: Represents the year for which the annual mean CO2 concentration is measured
#
# Uncertainty: The uncertainty associated with the annual mean CO2 concentration, also measured in parts per million (ppm).
#
# Annual Increase: Represents the year-over-year change in the concentration of atmospheric CO2, measured in parts per million (ppm)</p>
# </div>

# %% [markdown]
# <div style= "background-color:#959494; padding: 10px;border-radius : 30px;text-align:center">
#     <h1>Analysis of dataset co2-annmean-gl</h1>
# </div>

# %%
df= pd.read_csv("/kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-annmean-gl.csv")
df
# Out:
#     Year    Mean  Uncertainty
# 0   1979  336.85         0.11
# 1   1980  338.91         0.07
# 2   1981  340.11         0.09
# 3   1982  340.86         0.03
# 4   1983  342.53         0.06
# 5   1984  344.07         0.08
# 6   1985  345.54         0.07
# 7   1986  346.97         0.07
# 8   1987  348.68         0.10
# 9   1988  351.16         0.07
# 10  1989  352.79         0.07
# 11  1990  354.06         0.07
# 12  1991  355.39         0.07
# 13  1992  356.09         0.06
# 14  1993  356.83         0.07
# 15  1994  358.33         0.08
# 16  1995  360.17         0.05
# 17  1996  361.93         0.04
# 18  1997  363.04         0.05
# 19  1998  365.70         0.04
# 20  1999  367.79         0.05
# 21  2000  368.96         0.06
# 22  2001  370.57         0.05
# 23  2002  372.58         0.04
# 24  2003  375.14         0.04
# 25  2004  376.95         0.06
# 26  2005  378.98         0.05
# 27  2006  381.15         0.05
# 28  2007  382.90         0.04
# 29  2008  385.02         0.05
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Year'],df['Mean'], marker='o', linestyle='-')
plt.title('Mean over Years')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.grid(True)
plt.show()

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows mean of CO2 emission over years globally which is gradually increasing.</h3>
# </div>

# %%
sns.pairplot(df)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows the relation among the dataset.</h3>
# </div>

# %% [markdown]
# <div style= "background-color:#959494; padding: 10px;border-radius : 30px;text-align:center">
#     <h1>Analysis of dataset co2-annmean-mlo</h1>
# </div>

# %%
df1= pd.read_csv("/kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-annmean-mlo.csv")
df1
# Out:
#     Year    Mean  Uncertainty
# 0   1959  315.98         0.12
# 1   1960  316.91         0.12
# 2   1961  317.64         0.12
# 3   1962  318.45         0.12
# 4   1963  318.99         0.12
# ..   ...     ...          ...
# 60  2019  411.65         0.12
# 61  2020  414.21         0.12
# 62  2021  416.41         0.12
# 63  2022  418.53         0.12
# 64  2023  421.08         0.12
#
# [65 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
plt.errorbar(df1['Year'], df1['Mean'], yerr=df1['Uncertainty'], fmt='*', linestyle='-',color="Red")
plt.title('Mean with Uncertainty over Years')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.grid(True)
plt.show()

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows mean of CO2 emission over years depicting the Country-wise scenario which is gradually increasing.</h3>
# </div>

# %%
sns.pairplot(df1)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows the relation among the dataset.</h3>
# </div>

# %% [markdown]
# <div style= "background-color:#959494; padding: 10px;border-radius : 30px;text-align:center">
#     <h1>Analysis of dataset co2-gr-gl</h1>
# </div>

# %%
df2= pd.read_csv("/kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-gr-gl.csv")
df2
# Out:
#     Year  Annual Increase  Uncertainty
# 0   1959             0.96         0.31
# 1   1960             0.71         0.27
# 2   1961             0.78         0.27
# 3   1962             0.56         0.27
# 4   1963             0.57         0.28
# ..   ...              ...          ...
# 59  2018             2.39         0.09
# 60  2019             2.52         0.06
# 61  2020             2.36         0.08
# 62  2021             2.46         0.08
# 63  2022             2.16         0.08
#
# [64 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
plt.errorbar(df2['Year'], df2['Annual Increase'], df2['Uncertainty'], fmt='o', linestyle='-')
plt.title('Annual Increase with Uncertainty over Years')
plt.xlabel('Year')
plt.ylabel('Annual Increase')
plt.grid(True)
plt.show()

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows global Annual increase in CO2 emission level with uncertainity over years which is gradually increasing slope.</h3>
# </div>

# %%
sns.pairplot(df2)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows the relation among the dataset.</h3>
# </div>

# %% [markdown]
# <div style= "background-color:#959494; padding: 10px;border-radius : 30px;text-align:center">
#     <h1>Analysis of dataset co2-gr-mlo</h1>
# </div>

# %%
df3= pd.read_csv("/kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-gr-mlo.csv")
df3
# Out:
#     Year  Annual Increase  Uncertainty
# 0   1959             0.94         0.11
# 1   1960             0.50         0.11
# 2   1961             0.96         0.11
# 3   1962             0.64         0.11
# 4   1963             0.71         0.11
# ..   ...              ...          ...
# 59  2018             2.85         0.11
# 60  2019             2.49         0.11
# 61  2020             2.32         0.11
# 62  2021             2.36         0.11
# 63  2022             1.81         0.11
#
# [64 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
plt.errorbar(df3['Year'],df3['Annual Increase'], df3['Uncertainty'], fmt='o', linestyle='-',color="red")
plt.title('Annual Increase with Uncertainty over Years')
plt.xlabel('Year')
plt.ylabel('Annual Increase')
plt.grid(True)
plt.show()

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows Annual increase in CO2 emission level with uncertainity over years depicting the Country-wise scenario which is gradually increasing slope.</h3>
# </div>

# %%
sns.pairplot(df3)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows the relation among the dataset.</h3>
# </div>

# %% [markdown]
# <div style= "background-color:#959494; padding: 10px;border-radius : 30px;text-align:center">
#     <h1>Analysis of dataset co2-mm-gl</h1>
# </div>

# %%
df4= pd.read_csv("/kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-mm-gl.csv")
df4
# Out:
#                     Date  Decimal Date  Average  Trend
# 1979-01 1979.042  336.56          0.11   335.92   0.09
# 1979-02 1979.125  337.29          0.09   336.25   0.10
# 1979-03 1979.208  337.88          0.11   336.51   0.10
# 1979-04 1979.292  338.32          0.12   336.72   0.10
# 1979-05 1979.375  338.26          0.03   336.71   0.10
# ...                  ...           ...      ...    ...
# 2023-07 2023.542  417.86          0.10   419.15   0.06
# 2023-08 2023.625  416.60          0.10   419.44   0.06
# 2023-09 2023.708  416.98          0.10   419.78   0.06
# 2023-10 2023.792  418.64          0.10   420.13   0.06
# 2023-11 2023.875  420.15          0.10   420.38   0.06
#
# [539 rows x 4 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(df4['Date'], df4['Average'], marker='o', linestyle='-', label='Average')
plt.plot(df4['Date'], df4['Trend'], marker='o', linestyle='-', label='Trend')
plt.title('Average and Trend over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.xticks(rotation=45) 
plt.legend()
plt.grid(True)
plt.tight_layout()  
plt.show()

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows Average CO2 emission and trend over years globally.</h3>
# </div>

# %%
sns.pairplot(df4)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows the relation among the dataset.</h3>
# </div>

# %% [markdown]
# <div style= "background-color:#959494; padding: 10px;border-radius : 30px;text-align:center">
#     <h1>Analysis of dataset co2-mm-mlo</h1>
# </div>

# %%
df5= pd.read_csv("/kaggle/input/global-trends-in-atmospheric-carbon-dioxide/co2-mm-mlo.csv")
df5
# Out:
#               Date  Decimal Date  Average  Interpolated  Trend  Number of Days
# 1958-03  1958.2027        315.70   314.43            -1  -9.99           -0.99
# 1958-04  1958.2877        317.45   315.16            -1  -9.99           -0.99
# 1958-05  1958.3699        317.51   314.71            -1  -9.99           -0.99
# 1958-06  1958.4548        317.24   315.14            -1  -9.99           -0.99
# 1958-07  1958.5370        315.86   315.18            -1  -9.99           -0.99
# ...            ...           ...      ...           ...    ...             ...
# 2023-09  2023.7083        418.51   421.96            18   0.30            0.14
# 2023-10  2023.7917        418.82   422.12            27   0.47            0.17
# 2023-11  2023.8750        420.46   422.43            21   0.91            0.38
# 2023-12  2023.9583        421.86   422.56            20   0.70            0.30
# 2024-01  2024.0417        422.80   422.53            27   0.60            0.22
#
# [791 rows x 6 columns]

# %%
plt.figure(figsize=(10, 6))

plt.plot(df5['Date'], df5['Average'], label='Average')
plt.plot(df5['Date'], df5['Interpolated'], label='Interpolated')
plt.plot(df5['Date'], df5['Trend'], label='Trend')


plt.title('Multiple Variables Over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows the Country-wise Average CO2 emission over years,The interpolated value of CO2 concentration over years,the value of CO2 concentration trend over years.</h3>
# </div>

# %%
sns.pairplot(df5)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 5px;border-radius : 30px;text-align:center">
#     <h3>It shows the relation among the dataset.</h3>
# </div>

# %% [markdown]
# <div style= "background-color:#959494; padding: 10px;border-radius : 30px;text-align:center">
#     <h1>Conclusion</h1>
# </div>

# %% [markdown]
# <div style= "background-color:#E1E1E1; padding: 10px;border-radius : 30px">
#     <p>
# Gradually Increasing Mean CO2 Emissions: The plot clearly shows that the mean CO2 emissions have been increasing steadily over the years. This indicates a consistent trend of rising carbon dioxide levels in the atmosphere.
#
# Increasing Uncertainty in Annual CO2 Emission Increase: The uncertainty in annual CO2 emission levels also appears to be increasing over time. This suggests that while the mean CO2 emissions are rising, there is also increasing variability or uncertainty in the annual changes in CO2 levels.
#
# Overall Trend of Rising CO2 Levels: Despite some fluctuations and uncertainty, the overall trend depicted by both the mean CO2 emissions and the uncertainty in annual increases points towards a continuous rise in CO2 levels over the years.
#
# Need for Further Analysis: While the pair plots provides valuable insights into the general trends, further analysis may be required to understand the underlying factors contributing to the observed increase in CO2 emissions and the increasing uncertainty in annual changes. This could involve examining potential drivers such as industrial activities, deforestation, and changes in land use, among others.
#
# In summary, EDA suggests a concerning trend of increasing CO2 emissions with a corresponding rise in uncertainty, highlighting the importance of continued monitoring and efforts to mitigate climate change.</p>
# </div>
